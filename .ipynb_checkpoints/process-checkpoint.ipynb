# %%
import pandas as pd
user = pd.read_csv("data/trainingset/train_base.csv")
op = pd.read_csv("data/trainingset/train_op.csv")
trans = pd.read_csv("data/trainingset/train_trans.csv")
label = pd.read_csv("data/trainingset/train_label.csv")

# %%
user.columns
# Out:
# Index(['user', 'sex', 'age', 'provider', 'level', 'verified', 'using_time',
#        'regist_type', 'card_a_cnt', 'card_b_cnt', 'card_c_cnt', 'agreement1',
#        'op1_cnt', 'op2_cnt', 'card_d_cnt', 'agreement_total', 'service1_cnt',
#        'service1_amt', 'service2_cnt', 'agreement2', 'agreement3',
#        'agreement4', 'acc_count', 'login_cnt_period1', 'login_cnt_period2',
#        'ip_cnt', 'login_cnt_avg', 'login_days_cnt', 'province', 'city',
#        'balance', 'balance_avg', 'balance1', 'balance1_avg', 'balance2',
#        'balance2_avg', 'service3', 'service3_level', 'product1_amount',
#        'product2_amount', 'product3_amount', 'product4_amount',
#        'product5_amount', 'product6_amount', 'product7_cnt',
#        'product7_fail_cnt'],
#       dtype='object')

# %%
# test_data.provider.unique()

# %%
# 合并 user 和 label 表
train_data = pd.merge(label, user, how="left", on="user")

# %%
# 数据处理（省份和城市未处理）
train_data["balance"] = train_data["balance"].map(lambda x: int(x.split(" ")[1]))
train_data["sex"].fillna("category -1", inplace=True)
train_data["sex"] = train_data["sex"].map(lambda x: int(x.split(" ")[1]))
train_data["provider"].fillna("category -1", inplace=True)
train_data["provider"] = train_data["provider"].map(lambda x: int(x.split(" ")[1]))
train_data["level"] = train_data["level"].map(lambda x: int(x.split(" ")[1]))
train_data["verified"] = train_data["verified"].map(lambda x: int(x.split(" ")[1]))
train_data["regist_type"] = train_data["regist_type"].map(lambda x: int(x.split(" ")[1]))
train_data["agreement1"] = train_data["agreement1"].map(lambda x: int(x.split(" ")[1]))
train_data["agreement2"] = train_data["agreement2"].map(lambda x: int(x.split(" ")[1]))
train_data["agreement3"] = train_data["agreement3"].map(lambda x: int(x.split(" ")[1]))
train_data["agreement4"] = train_data["agreement4"].map(lambda x: int(x.split(" ")[1]))
train_data["balance_avg"].fillna("level  -1", inplace=True)
train_data["balance_avg"] = train_data["balance_avg"].map(lambda x: int(x.split(" ")[1]))
train_data["balance2"] = train_data["balance2"].map(lambda x: int(x.split(" ")[1]))
train_data["balance2_avg"] = train_data["balance2_avg"].map(lambda x: int(x.split(" ")[1]))
train_data["service3"] = train_data["service3"].map(lambda x: int(x.split(" ")[1]))
train_data["service3_level"].fillna("level  -1", inplace=True)
train_data["service3_level"] = train_data["service3_level"].map(lambda x: int(x.split(" ")[1]))
train_data["product1_amount"] = train_data["product1_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["product2_amount"] = train_data["product2_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["product3_amount"] = train_data["product3_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["product4_amount"] = train_data["product4_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["product5_amount"] = train_data["product5_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["product6_amount"] = train_data["product6_amount"].map(lambda x: int(x.split(" ")[1]))
train_data["balance1_avg"].fillna("level  -1", inplace=True)
train_data["balance1_avg"] = train_data["balance1_avg"].map(lambda x: int(x.split(" ")[1]))
train_data["balance1"].fillna("level  -1", inplace=True)
train_data["balance1"] = train_data["balance1"].map(lambda x: int(x.split(" ")[1]))



min_age = train_data["age"].min()
train_data["age"] = train_data["age"].map(lambda x: x - min_age)
min_age = train_data["card_a_cnt"].min()
train_data["card_a_cnt"] = train_data["card_a_cnt"].map(lambda x: x - min_age)
min_age = train_data["card_b_cnt"].min()
train_data["card_b_cnt"] = train_data["card_b_cnt"].map(lambda x: x - min_age)
min_age = train_data["card_c_cnt"].min()
train_data["card_c_cnt"] = train_data["card_c_cnt"].map(lambda x: x - min_age)
min_age = train_data["card_d_cnt"].min()
train_data["card_d_cnt"] = train_data["card_d_cnt"].map(lambda x: x - min_age)
min_age = train_data["op1_cnt"].min()
train_data["op1_cnt"] = train_data["op1_cnt"].map(lambda x: x - min_age)
min_age = train_data["op2_cnt"].min()
train_data["op2_cnt"] = train_data["op2_cnt"].map(lambda x: x - min_age)
min_age = train_data["agreement_total"].min()
train_data["agreement_total"] = train_data["agreement_total"].map(lambda x: x - min_age)
min_age = train_data["service1_cnt"].min()
train_data["service1_cnt"] = train_data["service1_cnt"].map(lambda x: x - min_age)
min_age = train_data["service1_amt"].min()
train_data["service1_amt"] = train_data["service1_amt"].map(lambda x: x - min_age)
min_age = train_data["service2_cnt"].min()
train_data["service2_cnt"] = train_data["service2_cnt"].map(lambda x: x - min_age)
min_age = train_data["acc_count"].min()
train_data["acc_count"] = train_data["acc_count"].map(lambda x: x - min_age)
min_age = train_data["login_cnt_period1"].min()
train_data["login_cnt_period1"] = train_data["login_cnt_period1"].map(lambda x: x - min_age)
min_age = train_data["login_cnt_period2"].min()
train_data["login_cnt_period2"] = train_data["login_cnt_period2"].map(lambda x: x - min_age)
min_age = train_data["ip_cnt"].min()
train_data["ip_cnt"] = train_data["ip_cnt"].map(lambda x: x - min_age)
min_age = train_data["login_cnt_avg"].min()
train_data["login_cnt_avg"] = train_data["login_cnt_avg"].map(lambda x: x - min_age)
min_age = train_data["login_days_cnt"].min()
train_data["login_days_cnt"] = train_data["login_days_cnt"].map(lambda x: x - min_age)
min_age = train_data["product7_cnt"].min()
train_data["product7_cnt"] = train_data["product7_cnt"].map(lambda x: x - min_age)
min_age = train_data["product7_fail_cnt"].min()
train_data["product7_fail_cnt"] = train_data["product7_fail_cnt"].map(lambda x: x - min_age)

# %%
# train_data["balance1"].fillna("level  -1", inplace=True)
# train_data["balance1"] = train_data["balance1"].map(lambda x: int(x.split(" ")[1]))

# %%
pd.set_option('display.max_columns',47) 
train_data.head(10)
# Out:
#           user  label  sex    age  provider  level  verified  using_time  \
# 0  Train_00000      0    0  24871         0      1         0       24712
# 1  Train_00001      1    0  24889         0      2         0       24716
# 2  Train_00002      0    0  24963         0      2         0       24736
# 3  Train_00003      0    0  24840         2      2         0       24719
# 4  Train_00004      0    0  24871         2      1         0       24707
# 5  Train_00005      0    0  24834         0      2         0       24719
# 6  Train_00006      0    0  24865         0      2         0       24738
# 7  Train_00007      0    0  24980         0      2         0       24735
# 8  Train_00008      0    1  24914         0      2         0       24717
# 9  Train_00009      0    0  24877         0      2         0       24728
#
#    regist_type  card_a_cnt  card_b_cnt  card_c_cnt  agreement1  op1_cnt  \
# 0            1       24712       24712       24706           0    24731
# ...

# %%
# 调整后 age 取值不均问题
import matplotlib.pyplot as plt
# %matplotlib inline
x=train_data.age.unique()
plt.hist(x,edgecolor="black",bins=20,color="white")
plt.title("Age")
plt.show()

# %%
# 模型训练
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

train_X = train_data[['sex','age','provider','level','verified','using_time','regist_type','card_a_cnt','card_b_cnt', 'card_c_cnt','agreement1','op1_cnt','op2_cnt','card_d_cnt','agreement_total','service1_cnt','service1_amt','service2_cnt','agreement2','agreement3','agreement4','acc_count','login_cnt_period1','login_cnt_period2','ip_cnt','login_cnt_avg','login_days_cnt','balance','balance_avg','balance1','balance1_avg', 'balance2','balance2_avg','service3','service3_level','product1_amount','product2_amount','product3_amount','product4_amount','product5_amount','product6_amount','product7_cnt','product7_fail_cnt']]
train_Y = train_data["label"]

X_train, X_test, y_train, y_test = train_test_split(train_X, train_Y, random_state=2020)

model = LogisticRegression()
model.fit(X_train, y_train)

print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# /Users/feedliu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7520649626074338
# 0.7541436464088398

# %%
# import numpy as np
# def plot_decision_boundary(model, axis):
#     x0, x1 = np.meshgrid(
#         np.linspace(axis[0], axis[1], int((axis[1] - axis[0]) * 100)).reshape(-1, 1),
#         np.linspace(axis[2], axis[3], int((axis[3] - axis[2]) * 100)).reshape(-1, 1),
#     )
#     X_new = np.c_[x0.ravel(), x1.ravel()]

#     y_predict = model.predict(X_new)
#     zz = y_predict.reshape(x0.shape)

#     custom_cmap = ListedColormap(['#EF9A9A', '#FFF59D', '#90CAF9'])

#     plt.contourf(x0, x1, zz, cmap=custom_cmap)
    
# plot_decision_boundary(model, axis=[0, 100, 0, 100])
# plt.show()

# %%
train_data["label"].unique()
# Out:
# array([0, 1])

# %%
# 查看某特征在 label 的分布
train_data.groupby(["label"])["age"].mean()
# Out:
# label
# 0    24913.402144
# 1    24904.302632
# Name: age, dtype: float64

# %%
train_data.groupby(["age"])["balance"].mean()
# Out:
# age
# 24706     2.205607
# 24810     5.000000
# 24829     7.769231
# 24834     7.755556
# 24840     7.077744
# 24846     7.693182
# 24853     8.273786
# 24859     8.827431
# 24865     8.727096
# 24871     9.079950
# 24877     8.975771
# 24883     9.287941
# 24889     9.583533
# 24895     9.637691
# 24901     9.751739
# 24908     9.876235
# 24914    10.027052
# 24920    10.213312
# 24925    10.278502
# 24931    10.248945
# 24938    10.129681
# 24944    10.516063
# 24950    10.417671
# 24956    10.908688
# 24963    10.502000
# 24969    10.505735
# 24974    10.795045
# 24980    10.335519
# 24986    10.906650
# 24993    10.551227
# 24999    10.586854
# 25005    11.117857
# 25011    11.369658
# 25018    12.061538
# 25023    10.878049
# 25029    11.024390
# 25035    11.842466
# 25041    11.615385
# 25048    10.465347
# 25054     7.250000
# 25060     1.000000
# 25065     1.000000
# 25109     4.000000
# 25114     1.500000
# 25120     1.000000
# 25158     3.000000
# 25194     1.000000
# ...

# %%
# 读取测试数据

test_user = pd.read_csv("data/testingset/test_a_base.csv")
test_op = pd.read_csv("data/testingset/test_a_op.csv")
test_trans = pd.read_csv("data/testingset/test_a_trans.csv")

test_data = test_user

# 数据处理（省份和城市未处理）
test_data["balance"] = test_data["balance"].map(lambda x: int(x.split(" ")[1]))
test_data["sex"].fillna("category -1", inplace=True)
test_data["sex"] = test_data["sex"].map(lambda x: int(x.split(" ")[1]))
test_data["provider"].fillna("category  -1", inplace=True)
test_data["provider"] = test_data["provider"].map(lambda x: int(x.split(" ")[1]))
test_data["level"] = test_data["level"].map(lambda x: int(x.split(" ")[1]))
test_data["verified"] = test_data["verified"].map(lambda x: int(x.split(" ")[1]))
test_data["regist_type"] = test_data["regist_type"].map(lambda x: int(x.split(" ")[1]))
test_data["agreement1"] = test_data["agreement1"].map(lambda x: int(x.split(" ")[1]))
test_data["agreement2"] = test_data["agreement2"].map(lambda x: int(x.split(" ")[1]))
test_data["agreement3"] = test_data["agreement3"].map(lambda x: int(x.split(" ")[1]))
test_data["agreement4"] = test_data["agreement4"].map(lambda x: int(x.split(" ")[1]))
test_data["balance_avg"].fillna("level  -1", inplace=True)
test_data["balance_avg"] = test_data["balance_avg"].map(lambda x: int(x.split(" ")[1]))
test_data["balance2"] = test_data["balance2"].map(lambda x: int(x.split(" ")[1]))
test_data["balance2_avg"] = test_data["balance2_avg"].map(lambda x: int(x.split(" ")[1]))
test_data["service3"] = test_data["service3"].map(lambda x: int(x.split(" ")[1]))
test_data["service3_level"].fillna("level  -1", inplace=True)
test_data["service3_level"] = test_data["service3_level"].map(lambda x: int(x.split(" ")[1]))
test_data["product1_amount"] = test_data["product1_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["product2_amount"] = test_data["product2_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["product3_amount"] = test_data["product3_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["product4_amount"] = test_data["product4_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["product5_amount"] = test_data["product5_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["product6_amount"] = test_data["product6_amount"].map(lambda x: int(x.split(" ")[1]))
test_data["balance1_avg"].fillna("level  -1", inplace=True)
test_data["balance1_avg"] = test_data["balance1_avg"].map(lambda x: int(x.split(" ")[1]))
test_data["balance1"].fillna("level  -1", inplace=True)
test_data["balance1"] = test_data["balance1"].map(lambda x: int(x.split(" ")[1]))



min_age = test_data["age"].min()
test_data["age"] = test_data["age"].map(lambda x: x - min_age)
min_age = test_data["card_a_cnt"].min()
test_data["card_a_cnt"] = test_data["card_a_cnt"].map(lambda x: x - min_age)
min_age = test_data["card_b_cnt"].min()
test_data["card_b_cnt"] = test_data["card_b_cnt"].map(lambda x: x - min_age)
min_age = test_data["card_c_cnt"].min()
test_data["card_c_cnt"] = test_data["card_c_cnt"].map(lambda x: x - min_age)
min_age = test_data["card_d_cnt"].min()
test_data["card_d_cnt"] = test_data["card_d_cnt"].map(lambda x: x - min_age)
min_age = test_data["op1_cnt"].min()
test_data["op1_cnt"] = test_data["op1_cnt"].map(lambda x: x - min_age)
min_age = test_data["op2_cnt"].min()
test_data["op2_cnt"] = test_data["op2_cnt"].map(lambda x: x - min_age)
min_age = test_data["agreement_total"].min()
test_data["agreement_total"] = test_data["agreement_total"].map(lambda x: x - min_age)
min_age = test_data["service1_cnt"].min()
test_data["service1_cnt"] = test_data["service1_cnt"].map(lambda x: x - min_age)
min_age = test_data["service1_amt"].min()
test_data["service1_amt"] = test_data["service1_amt"].map(lambda x: x - min_age)
min_age = test_data["service2_cnt"].min()
test_data["service2_cnt"] = test_data["service2_cnt"].map(lambda x: x - min_age)
min_age = test_data["acc_count"].min()
test_data["acc_count"] = test_data["acc_count"].map(lambda x: x - min_age)
min_age = test_data["login_cnt_period1"].min()
test_data["login_cnt_period1"] = test_data["login_cnt_period1"].map(lambda x: x - min_age)
min_age = test_data["login_cnt_period2"].min()
test_data["login_cnt_period2"] = test_data["login_cnt_period2"].map(lambda x: x - min_age)
min_age = test_data["ip_cnt"].min()
test_data["ip_cnt"] = test_data["ip_cnt"].map(lambda x: x - min_age)
min_age = test_data["login_cnt_avg"].min()
test_data["login_cnt_avg"] = test_data["login_cnt_avg"].map(lambda x: x - min_age)
min_age = test_data["login_days_cnt"].min()
test_data["login_days_cnt"] = test_data["login_days_cnt"].map(lambda x: x - min_age)
min_age = test_data["product7_cnt"].min()
test_data["product7_cnt"] = test_data["product7_cnt"].map(lambda x: x - min_age)
min_age = test_data["product7_fail_cnt"].min()
test_data["product7_fail_cnt"] = test_data["product7_fail_cnt"].map(lambda x: x - min_age)

# %%
test_data.provider.unique()
# Out:
# array([ 0,  2,  1, -1])

# %%
type(test_data.provider)
# Out:
# pandas.core.series.Series

# %%
test_X = test_data[['sex','age','provider','level','verified','using_time','regist_type','card_a_cnt','card_b_cnt', 'card_c_cnt','agreement1','op1_cnt','op2_cnt','card_d_cnt','agreement_total','service1_cnt','service1_amt','service2_cnt','agreement2','agreement3','agreement4','acc_count','login_cnt_period1','login_cnt_period2','ip_cnt','login_cnt_avg','login_days_cnt','balance','balance_avg','balance1','balance1_avg', 'balance2','balance2_avg','service3','service3_level','product1_amount','product2_amount','product3_amount','product4_amount','product5_amount','product6_amount','product7_cnt','product7_fail_cnt']]

predict_y = model.predict(test_X)

# %%
test_data["label"] = pd.Series(predict_y)

test_data[["user", "label"]].to_csv("baseline2.csv", header=["user", "prob"], index=False)
